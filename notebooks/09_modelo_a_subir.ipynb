# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

import joblib
from src.features.preprocessing_4classes import preprocessing
from src.models.tune_best_model import tune_lightgbm

df, X, y = preprocessing()

best_model, best_params, report, metrics = tune_lightgbm(X, y, n_iter=20, cv=3)

os.makedirs("../models", exist_ok=True)
joblib.dump(best_model, "../models/modelo_final_lightgbm_4clases.joblib")
# Out:
# Buscando mejores hiperparámetros (20 combinaciones, 3 folds)...
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
#
# Mejores parámetros encontrados:
#   classifier__colsample_bytree: 0.7597870996690186
#   classifier__learning_rate: 0.04184404372168336
#   classifier__max_depth: 7
#   classifier__min_child_samples: 39
#   classifier__n_estimators: 530
#   classifier__num_leaves: 87
#   classifier__reg_alpha: 0.061043977350336676
#   classifier__reg_lambda: 1.2125956761539498
#   classifier__subsample: 0.9173899545410138
#
# Resultados en test:
#   F1 Macro:    0.6868
#   F1 Weighted: 0.6888
#   Accuracy:    0.6867
#
# Diagnóstico: OK — modelo bien calibrado
# ['../models/modelo_final_lightgbm_4clases.joblib']

# %%
modelo_4 = joblib.load("../models/modelo_final_lightgbm_4clases.joblib")
modelo_4.classes_
# Out:
# array(['acoustic', 'mainstream', 'other', 'urban'], dtype=object)
